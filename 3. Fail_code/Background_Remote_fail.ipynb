# %%
from PIL import Image

#파이썬에서 그림 열기로 이미지 보여주는 코드
im = Image.open('C:/Users/HOME/Desktop/수DA쟁이/TEAMPROJECT-씨앗/train_jpg/train/Black-grass/0.jpg') # 이미지 불러오기
im.show() # 이미지 보여주기

# %%
scale = 70
seed = 7
path_to_images = 'C:/Users/HOME/Desktop/수DA쟁이/TEAMPROJECT-씨앗/train_jpg/train/*/*.jpg'
images = glob(path_to_images)
trainingset = []
traininglabels = []
num = len(images)
count = 1
#READING IMAGES AND RESIZING THEM
for i in images:
    print(str(count)+'/'+str(num),end='\r')
    trainingset.append(cv2.resize(cv2.imread(i),(scale,scale)))
    traininglabels.append(i.split('/')[-2])
    count=count+1
trainingset = np.asarray(trainingset)
traininglabels = pd.DataFrame(traininglabels)
# Out:
# 1/3803
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-61-bf193699351e> in <module>
#      10 for i in images:
#      11     print(str(count)+'/'+str(num),end='\r')
# ---> 12     trainingset.append(cv2.resize(cv2.imread(i),(scale,scale)))
#      13     traininglabels.append(i.split('/')[-2])
#      14     count=count+1
#
# error: OpenCV(4.4.0) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-2b5g8ysb\opencv\modules\imgproc\src\resize.cpp:3929: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'

# %%
import cv2
from glob import glob
import numpy as np
from matplotlib import pyplot as plt
import math
import pandas as pd

new_train = []
sets = [] ; getEx = True
#path = "C:/Users/HOME/Desktop/수DA쟁이/TEAMPROJECT-씨앗/train_jpg/train/Black-grass/0.jpg"
#i = glob(path)
for i in trainingset:
    blurr = cv2.GaussianBlur(i,(5,5),0)
    hsv = cv2.cvtColor(blurr,cv2.COLOR_BGR2HSV)
        #GREEN PARAMETERS
    lower = (20,40,40)
    upper = (75,255,255)
    mask = cv2.inRange(hsv,lower,upper)
    struc = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(11,11))
    mask = cv2.morphologyEx(mask,cv2.MORPH_CLOSE,struc)
    boolean = mask>0
    new = np.zeros_like(i,np.uint8)
    new[boolean] = i[boolean]
    new_train.append(new)

    if getEx:
        plt.subplot(2,3,1);plt.imshow(i) # ORIGINAL
        plt.subplot(2,3,2);plt.imshow(blurr) # BLURRED
        plt.subplot(2,3,3);plt.imshow(hsv) # HSV CONVERTED
        plt.subplot(2,3,4);plt.imshow(mask) # MASKED
        plt.subplot(2,3,5);plt.imshow(boolean) # BOOLEAN MASKED
        plt.subplot(2,3,6);plt.imshow(new) # NEW PROCESSED IMAGE
        plt.show()
        getEx = False
new_train = np.asarray(new_train)

for i in range(8):
    plt.subplot(2,4,i+1)
    plt.imshow(new_train[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-60-a5984346e030> in <module>
#      37 for i in range(8):
#      38     plt.subplot(2,4,i+1)
# ---> 39     plt.imshow(new_train[i])
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
im = Image.open("C:/Users/HOME/Desktop/수DA쟁이/TEAMPROJECT-씨앗/train_jpg/train/Charlock/7.jpg")
a = np.array(im)
plt.imshow(a)

# %%
import cv2
from glob import glob
import numpy as np
from matplotlib import pyplot as plt
import math
import pandas as pd

new_train = []
sets = [] ; getEx = True
#path = "C:/Users/HOME/Desktop/수DA쟁이/TEAMPROJECT-씨앗/train_jpg/train/Black-grass/0.jpg"
#i = glob(path)
blurr = cv2.GaussianBlur(a,(5,5),0)
hsv = cv2.cvtColor(blurr,cv2.COLOR_BGR2HSV)
    #GREEN PARAMETERS
lower = (20,40,40)
upper = (75,255,255)
mask = cv2.inRange(hsv,lower,upper)
struc = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(11,11))
mask = cv2.morphologyEx(mask,cv2.MORPH_CLOSE,struc)
boolean = mask>0
new = np.zeros_like(a,np.uint8)
new[boolean] = a[boolean]
new_train.append(new)

if getEx:
    plt.subplot(2,3,1);plt.imshow(a) # ORIGINAL
    plt.subplot(2,3,2);plt.imshow(blurr) # BLURRED
    plt.subplot(2,3,3);plt.imshow(hsv) # HSV CONVERTED
    plt.subplot(2,3,4);plt.imshow(mask) # MASKED
    plt.subplot(2,3,5);plt.imshow(boolean) # BOOLEAN MASKED
    plt.subplot(2,3,6);plt.imshow(new) # NEW PROCESSED IMAGE
    plt.show()
    getEx = False

# %%
pix = np.array(im)
plt.imshow(pix)

# %%
from PIL import ImageFilter
image2 = im.filter(ImageFilter.FIND_EDGES)
#image2.show()

pix2 = np.array(image2)
plt.imshow(pix2)

# %%
import cv2
from glob import glob
import numpy as np
from matplotlib import pyplot as plt
import math
import pandas as pd

new_train = []
sets = [] ; getEx = True
#path = "C:/Users/HOME/Desktop/수DA쟁이/TEAMPROJECT-씨앗/train_jpg/train/Black-grass/0.jpg"
#i = glob(path)
blurr = cv2.GaussianBlur(pix2,(5,5),0)
hsv = cv2.cvtColor(blurr,cv2.COLOR_BGR2HSV) #RGB TO HSV 변환
    #GREEN PARAMETERS
lower = (25,40,50)
upper = (75,255,255)
mask = cv2.inRange(hsv,lower,upper)
struc = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(11,11))
mask = cv2.morphologyEx(mask,cv2.MORPH_CLOSE,struc)
boolean = mask>0
new = np.zeros_like(pix2,np.uint8)
new[boolean] = pix2[boolean]
new_train.append(new)

if getEx:
    plt.subplot(2,3,1);plt.imshow(pix2) # ORIGINAL
    plt.subplot(2,3,2);plt.imshow(blurr) # BLURRED
    plt.subplot(2,3,3);plt.imshow(hsv) # HSV CONVERTED
    plt.subplot(2,3,4);plt.imshow(mask) # MASKED
    plt.subplot(2,3,5);plt.imshow(boolean) # BOOLEAN MASKED
    plt.subplot(2,3,6);plt.imshow(new) # NEW PROCESSED IMAGE
    plt.show()
    getEx = False

# %%
from PIL import ImageFilter
image3 = im.filter(ImageFilter.EMBOSS)
#image2.show()

pix3 = np.array(image3)
plt.imshow(pix3)
